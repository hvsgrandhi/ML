# %%
import pandas as pd

# %%
temp_data = pd.read_csv("/content/temperatures.csv")

# %%
temp_data

# %%
temp_data.describe()

# %%
temp_data.dtypes

# %%
temp_data.columns

# %%
temp_data.isnull().sum()

# %%
top5_data = temp_data.nlargest(5,"ANNUAL")

# %%
top10_data = temp_data.nlargest(10,"ANNUAL")

# %%
top10_data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.title("Top 10 Temperatures")
sns.barplot(x = top10_data.YEAR, y = top10_data.ANNUAL)

# %%
sns.set_style("whitegrid")

# %%
sns.boxplot(y = "YEAR", data = top10_data)

# %%
sns.boxplot(y = "JAN", data = top10_data)

# %%
sns.boxplot(y = "JAN", x = "YEAR",data = top10_data)

# %%
sns.boxplot(x = "JAN", y = "YEAR",data = temp_data)

# %%
sns.boxplot(y = "JAN", data = temp_data)

# %%
sns.heatmap(data = temp_data, vmin = 20, vmax = 40)

# %%
sns.boxplot(x = "MAY", data = temp_data)

# %%
sns.histplot(x = "YEAR", y = "JAN", data = temp_data)

# %%
from sklearn import linear_model, metrics

# %%
X = temp_data[["YEAR"]]
Y = temp_data[["ANNUAL"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 1)

# %%
len(X_train)

# %%
len(X_test)

# %%
reg = linear_model.LinearRegression()

# %%
model = reg.fit(X_train, Y_train)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred

# %%
print(Y_test)

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train, reg.predict(X_train),color = "red")
plt.show

# %%
plt.scatter(X_test, Y_test)
plt.plot(X_test, reg.predict(X_test),color = "green")
plt.show

# %%
print(model.intercept_)

# %%
print(model.coef_)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
print(mean_squared_error (Y_test, Y_pred))

# %%
print(mean_absolute_error (Y_test, Y_pred))

# %%
print(r2_score (Y_test, Y_pred))
